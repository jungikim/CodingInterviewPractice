# %%
"""
https://leetcode.com/problems/text-justification/

Given an array of strings words and a width maxWidth, 
format the text such that 
each line has exactly maxWidth characters and is fully (left and right) justified.

You should pack your words in a greedy approach;
that is, pack as many words as you can in each line.
Pad extra spaces ' ' when necessary so that each line has exactly maxWidth characters.

Extra spaces between words should be distributed as evenly as possible.
If the number of spaces on a line does not divide evenly between words, 
the empty slots on the left will be assigned more spaces than the slots on the right.

For the last line of text, it should be left-justified, and no extra space is inserted between words.

Note:
A word is defined as a character sequence consisting of non-space characters only.
Each word's length is guaranteed to be greater than 0 and not exceed maxWidth.
The input array words contains at least one word.
 
Constraints:
1 <= words.length <= 300
1 <= words[i].length <= 20
words[i] consists of only English letters and symbols.
1 <= maxWidth <= 100
words[i].length <= maxWidth
"""

def fullJustify(words, maxWidth):
    retVal = []
    wIdx = 0
    curLine = []
    curNW = 0
    def _leftAdjust(l, maxWidth):
        _l = ' '.join(l.split())
        _l = _l + ' '*(maxWidth - len(_l))
        return _l

    def _addNewLine(lines, line, numNonWhiteChars, maxWidth):
        if len(line) <= 1:
            lines.append(_leftAdjust(' '.join(line), maxWidth))
            return
        numWords = len(line)
        numGaps = len(line)-1
        gapWidths = [1] * numGaps + [0]
        while maxWidth - numNonWhiteChars - sum(gapWidths) > 0:
            for i in range(numGaps):
                if maxWidth - numNonWhiteChars - sum(gapWidths) > 0:
                    gapWidths[i] += 1
                
        newLine = ''.join([word + ' '*gap for word,gap in zip(line, gapWidths)])
        lines.append(newLine)

    while wIdx < len(words):
        if curNW + len(curLine) + len(words[wIdx]) > maxWidth:
            _addNewLine(retVal, curLine, curNW, maxWidth)
            curLine = []
            curNW = 0
        curLine.append(words[wIdx])
        curNW += len(words[wIdx])
        wIdx += 1
    if len(curLine)>0:
        _addNewLine(retVal, curLine, curNW, maxWidth)
    if len(retVal)>0:
        retVal[-1] = _leftAdjust(retVal[-1], maxWidth)
    return retVal

tests = [
(["This", "is", "an", "example", "of", "text", "justification."],
 16,
 [ "This    is    an",
   "example  of text",
   "justification.  "]),
(["What", "must", "be", "acknowledgment", "shall", "be"],
 16,
 ["What   must   be",
  "acknowledgment  ",
  "shall be        "]),
    # the last line is "shall be    " instead of "shall     be", because the last line must be left-justified instead of fully-justified.
    # the second line is also left-justified because it contains only one word.
(["Science","is","what","we","understand","well","enough","to","explain","to","a","computer.","Art","is","everything","else","we","do"], 20, [
  "Science  is  what we",
  "understand      well",
  "enough to explain to",
  "a  computer.  Art is",
  "everything  else  we",
  "do                  "]), 
]
for t in tests:
    retVal = fullJustify(t[0], t[1])
    # print(t[0], t[1])
    # for l in t[2]:
    #     print("\""+l+"\"")
    # for l in retVal:
    #     print("\""+l+"\"")
    assert(retVal == t[2])
